# %% [markdown]
# # Ray Data
# :label:`ray-data`

# %%
# Hide code
# Hide outputs
import ray

if ray.is_initialized:
    ray.shutdown()

ray.init()
# Out:
# 2023-08-28 13:28:32,162	INFO worker.py:1544 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.10.9', ray_version='2.3.0', ray_commit='cf7a56b4b0b648c324722df7c99c168e92ff0b45', address_info={'node_ip_address': '127.0.0.1', 'raylet_ip_address': '127.0.0.1', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-08-28_13-28-28_837971_39819/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-08-28_13-28-28_837971_39819/sockets/raylet', 'webui_url': '127.0.0.1:8265', 'session_dir': '/tmp/ray/session_2023-08-28_13-28-28_837971_39819', 'metrics_export_port': 62198, 'gcs_address': '127.0.0.1:63171', 'address': '127.0.0.1:63171', 'dashboard_agent_listen_port': 52365, 'node_id': '8cbd1c2c9d7a9515af5478abded87c3c3e5f2539eb3f17401a01c489'})

# %%
dataset = ray.data.read_parquet(
    "s3://anyscale-training-data/intro-to-ray-air/nyc_taxi_2021.parquet"
)
# Out:
# Parquet Files Sample:   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-08-28 13:34:13,632	WARNING read_api.py:330 -- ⚠️  The number of blocks in this dataset (1) limits its parallelism to 1 concurrent tasks. This is much less than the number of available CPU slots in the cluster. Use `.repartition(n)` to increase the number of dataset blocks.
